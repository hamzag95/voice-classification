# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import glob
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
# %matplotlib inline

from __future__ import unicode_literals
import youtube_dl

import subprocess

from IPython.display import Audio

# %% [markdown]
# ## Download Audio from List of Youtube Links

# %%
with open('./test_YT_list.txt', 'r') as f:
    vid_list = [line.strip() for line in f]
    
profiles = {}
curr_profile = 0
    
for line in vid_list:
    if line.startswith("http") is False:
        curr_profile = line
        profiles[curr_profile] = []
    else:
        profiles[curr_profile].append(line)

# %%
from __future__ import unicode_literals
import youtube_dl

for key in profiles:    
    ydl_opts = {
        'format': 'bestaudio/best',
        'noplaylist': True,
        'outtmpl': './data/wav_files/' + key + '/%(title)s.%(ext)s',
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'wav',
            'preferredquality': '192',
        }],
    }

    for URL in profiles[key]:
        with youtube_dl.YoutubeDL(ydl_opts) as ydl:
            ydl.download([URL])
# Out:
# [youtube] GMWFieBGR7c: Downloading webpage
# [youtube] GMWFieBGR7c: Downloading video info webpage
# [youtube] GMWFieBGR7c: Extracting video information
# [youtube] GMWFieBGR7c: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Oprah/Oprah Winfrey Harvard Commencement speech _ Harvard Commencement 2013.m4a
# [download] 100% of 26.33MiB in 00:56.71KiB/s ETA 00:00
# [ffmpeg] Correcting container in "./data/wav_files/Oprah/Oprah Winfrey Harvard Commencement speech _ Harvard Commencement 2013.m4a"
# [ffmpeg] Destination: ./data/wav_files/Oprah/Oprah Winfrey Harvard Commencement speech _ Harvard Commencement 2013.wav
# Deleting original file ./data/wav_files/Oprah/Oprah Winfrey Harvard Commencement speech _ Harvard Commencement 2013.m4a (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video vOppzHpvTiQ because of --no-playlist
# [youtube] vOppzHpvTiQ: Downloading webpage
# [youtube] vOppzHpvTiQ: Downloading video info webpage
# [youtube] vOppzHpvTiQ: Extracting video information
# [youtube] vOppzHpvTiQ: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Sriraj/How to Make a Prediction - Intro to Deep Learning #1.webm
# [download] 100% of 7.50MiB in 00:14.39KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Sriraj/How to Make a Prediction - Intro to Deep Learning #1.wav
# Deleting original file ./data/wav_files/Sriraj/How to Make a Prediction - Intro to Deep Learning #1.webm (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video XdM6ER7zTLk because of --no-playlist
# [youtube] XdM6ER7zTLk: Downloading webpage
# [youtube] XdM6ER7zTLk: Downloading video info webpage
# [youtube] XdM6ER7zTLk: Extracting video information
# [youtube] XdM6ER7zTLk: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Sriraj/How to Do Linear Regression using Gradient Descent.webm
# [download] 100% of 53.83MiB in 01:47.48KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Sriraj/How to Do Linear Regression using Gradient Descent.wav
# Deleting original file ./data/wav_files/Sriraj/How to Do Linear Regression using Gradient Descent.webm (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video cIVpemcoAlY because of --no-playlist
# [youtube] cIVpemcoAlY: Downloading webpage
# [youtube] cIVpemcoAlY: Downloading video info webpage
# [youtube] cIVpemcoAlY: Extracting video information
# [youtube] cIVpemcoAlY: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Patrick/❖ A Way to remember the Entire Unit Circle for Trigonometry ❖.webm
# [download] 100% of 5.95MiB in 00:11.48KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Patrick/❖ A Way to remember the Entire Unit Circle for Trigonometry ❖.wav
# Deleting original file ./data/wav_files/Patrick/❖ A Way to remember the Entire Unit Circle for Trigonometry ❖.webm (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video HYSI-AHUqRM because of --no-playlist
# [youtube] HYSI-AHUqRM: Downloading webpage
# [youtube] HYSI-AHUqRM: Downloading video info webpage
# [youtube] HYSI-AHUqRM: Extracting video information
# [youtube] HYSI-AHUqRM: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Patrick/What is a Limit Basic Idea of Limits.webm
# [download] 100% of 5.14MiB in 00:11.93KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Patrick/What is a Limit Basic Idea of Limits.wav
# Deleting original file ./data/wav_files/Patrick/What is a Limit Basic Idea of Limits.webm (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video aw_VM_ZDeIo because of --no-playlist
# [youtube] aw_VM_ZDeIo: Downloading webpage
# [youtube] aw_VM_ZDeIo: Downloading video info webpage
# [youtube] aw_VM_ZDeIo: Extracting video information
# [youtube] aw_VM_ZDeIo: Downloading js player vflaLKk05
# [youtube] aw_VM_ZDeIo: Downloading js player vflaLKk05
# [youtube] aw_VM_ZDeIo: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Patrick/❖ Basic Integration Problems.m4a
# [download] 100% of 9.19MiB in 00:25.98KiB/s ETA 00:00
# [ffmpeg] Correcting container in "./data/wav_files/Patrick/❖ Basic Integration Problems.m4a"
# [ffmpeg] Destination: ./data/wav_files/Patrick/❖ Basic Integration Problems.wav
# Deleting original file ./data/wav_files/Patrick/❖ Basic Integration Problems.m4a (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video Gi8_a7NlKAQ because of --no-playlist
# [youtube] Gi8_a7NlKAQ: Downloading webpage
# [youtube] Gi8_a7NlKAQ: Downloading video info webpage
# [youtube] Gi8_a7NlKAQ: Extracting video information
# [youtube] Gi8_a7NlKAQ: Downloading js player vfl32FIDY
# [youtube] Gi8_a7NlKAQ: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Patrick/Approximating a Definite Integral Using Rectangles.webm
# [download] 100% of 7.52MiB in 00:16.47KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Patrick/Approximating a Definite Integral Using Rectangles.wav
# Deleting original file ./data/wav_files/Patrick/Approximating a Definite Integral Using Rectangles.webm (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video odhAVmAahb4 because of --no-playlist
# [youtube] odhAVmAahb4: Downloading webpage
# [youtube] odhAVmAahb4: Downloading video info webpage
# [youtube] odhAVmAahb4: Extracting video information
# [youtube] odhAVmAahb4: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Patrick/Vector Basics - Algebraic Representations.webm
# [download] 100% of 5.07MiB in 00:17.15KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Patrick/Vector Basics - Algebraic Representations.wav
# Deleting original file ./data/wav_files/Patrick/Vector Basics - Algebraic Representations.webm (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video IUzoNG4-MIc because of --no-playlist
# [youtube] IUzoNG4-MIc: Downloading webpage
# [youtube] IUzoNG4-MIc: Downloading video info webpage
# [youtube] IUzoNG4-MIc: Extracting video information
# [youtube] IUzoNG4-MIc: Downloading js player vfl32FIDY
# [youtube] IUzoNG4-MIc: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Patrick/Vector Basics - Algebraic Representations Part 2.m4a
# [download] 100% of 3.79MiB in 00:07.99KiB/s ETA 00:00
# [ffmpeg] Correcting container in "./data/wav_files/Patrick/Vector Basics - Algebraic Representations Part 2.m4a"
# [ffmpeg] Destination: ./data/wav_files/Patrick/Vector Basics - Algebraic Representations Part 2.wav
# Deleting original file ./data/wav_files/Patrick/Vector Basics - Algebraic Representations Part 2.m4a (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video 3ULXhiJqlPs because of --no-playlist
# [youtube] 3ULXhiJqlPs: Downloading webpage
# [youtube] 3ULXhiJqlPs: Downloading video info webpage
# [youtube] 3ULXhiJqlPs: Extracting video information
# [youtube] 3ULXhiJqlPs: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Patrick/❖ Long Division of Numbers - Arithmetic Basics, Ex 1 ❖.m4a
# [download] 100% of 3.79MiB in 00:15.80KiB/s ETA 00:00
# [ffmpeg] Correcting container in "./data/wav_files/Patrick/❖ Long Division of Numbers - Arithmetic Basics, Ex 1 ❖.m4a"
# [ffmpeg] Destination: ./data/wav_files/Patrick/❖ Long Division of Numbers - Arithmetic Basics, Ex 1 ❖.wav
# Deleting original file ./data/wav_files/Patrick/❖ Long Division of Numbers - Arithmetic Basics, Ex 1 ❖.m4a (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video Im0VnXfYSns because of --no-playlist
# [youtube] Im0VnXfYSns: Downloading webpage
# [youtube] Im0VnXfYSns: Downloading video info webpage
# [youtube] Im0VnXfYSns: Extracting video information
# [youtube] Im0VnXfYSns: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Patrick/Arithmetic Basics - Finding the Percent of a Number.m4a
# [download] 100% of 5.51MiB in 00:11.59KiB/s ETA 00:00
# [ffmpeg] Correcting container in "./data/wav_files/Patrick/Arithmetic Basics - Finding the Percent of a Number.m4a"
# [ffmpeg] Destination: ./data/wav_files/Patrick/Arithmetic Basics - Finding the Percent of a Number.wav
# Deleting original file ./data/wav_files/Patrick/Arithmetic Basics - Finding the Percent of a Number.m4a (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video 9K1xx6wfN-U because of --no-playlist
# [youtube] 9K1xx6wfN-U: Downloading webpage
# [youtube] 9K1xx6wfN-U: Downloading video info webpage
# [youtube] 9K1xx6wfN-U: Extracting video information
# [youtube] 9K1xx6wfN-U: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Patrick/Sequences - Examples showing convergence or divergence.webm
# [download] 100% of 5.75MiB in 00:10.59KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Patrick/Sequences - Examples showing convergence or divergence.wav
# Deleting original file ./data/wav_files/Patrick/Sequences - Examples showing convergence or divergence.webm (pass -k to keep)
# 0
# [youtube] AAW7WRFBKdw: Downloading webpage
# [youtube] AAW7WRFBKdw: Downloading video info webpage
# [youtube] AAW7WRFBKdw: Extracting video information
# [youtube] AAW7WRFBKdw: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Patrick/Properties of Logarithms - Everything You Need to Know!.webm
# [download] 100% of 18.50MiB in 00:54.03KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Patrick/Properties of Logarithms - Everything You Need to Know!.wav
# Deleting original file ./data/wav_files/Patrick/Properties of Logarithms - Everything You Need to Know!.webm (pass -k to keep)
# 0
# [youtube] UzLMhqg3_Wc: Downloading webpage
# [youtube] UzLMhqg3_Wc: Downloading video info webpage
# [youtube] UzLMhqg3_Wc: Extracting video information
# [youtube] UzLMhqg3_Wc: Downloading MPD manifest
# [dashsegments] Total fragments: 166
# [download] Destination: ./data/wav_files/Tushar/System Design Introduction For Interview..m4a
# [download] 100% of 24.87MiB in 02:123.81KiB/s ETA 00:0034
# [ffmpeg] Correcting container in "./data/wav_files/Tushar/System Design Introduction For Interview..m4a"
# [ffmpeg] Destination: ./data/wav_files/Tushar/System Design Introduction For Interview..wav
# Deleting original file ./data/wav_files/Tushar/System Design Introduction For Interview..m4a (pass -k to keep)
# 0
# [youtube] zKPNUMkwOJE: Downloading webpage
# [youtube] zKPNUMkwOJE: Downloading video info webpage
# [youtube] zKPNUMkwOJE: Extracting video information
# [youtube] zKPNUMkwOJE: Downloading MPD manifest
# [dashsegments] Total fragments: 177
# [download] Destination: ./data/wav_files/Tushar/System Design  - Design messaging_chat service like Facebook Messenger or Whatsapp.m4a
# [download] 100% of 26.59MiB in 02:036.00KiB/s ETA 00:00229
# [ffmpeg] Correcting container in "./data/wav_files/Tushar/System Design  - Design messaging_chat service like Facebook Messenger or Whatsapp.m4a"
# [ffmpeg] Destination: ./data/wav_files/Tushar/System Design  - Design messaging_chat service like Facebook Messenger or Whatsapp.wav
# Deleting original file ./data/wav_files/Tushar/System Design  - Design messaging_chat service like Facebook Messenger or Whatsapp.m4a (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video 8LusJS5-AGo because of --no-playlist
# [youtube] 8LusJS5-AGo: Downloading webpage
# [youtube] 8LusJS5-AGo: Downloading video info webpage
# [youtube] 8LusJS5-AGo: Extracting video information
# [youtube] 8LusJS5-AGo: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Tushar/0_1 Knapsack Problem Dynamic Programming.m4a
# [download] 100% of 14.38MiB in 01:22.48KiB/s ETA 00:00
# [ffmpeg] Correcting container in "./data/wav_files/Tushar/0_1 Knapsack Problem Dynamic Programming.m4a"
# [ffmpeg] Destination: ./data/wav_files/Tushar/0_1 Knapsack Problem Dynamic Programming.wav
# Deleting original file ./data/wav_files/Tushar/0_1 Knapsack Problem Dynamic Programming.m4a (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video NnD96abizww because of --no-playlist
# [youtube] NnD96abizww: Downloading webpage
# [youtube] NnD96abizww: Downloading video info webpage
# [youtube] NnD96abizww: Extracting video information
# [youtube] NnD96abizww: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Tushar/Longest Common Subsequence.m4a
# [download] 100% of 7.18MiB in 00:23.07KiB/s ETA 00:00
# [ffmpeg] Correcting container in "./data/wav_files/Tushar/Longest Common Subsequence.m4a"
# [ffmpeg] Destination: ./data/wav_files/Tushar/Longest Common Subsequence.wav
# Deleting original file ./data/wav_files/Tushar/Longest Common Subsequence.m4a (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video ZM-sV9zQPEs because of --no-playlist
# [youtube] ZM-sV9zQPEs: Downloading webpage
# [youtube] ZM-sV9zQPEs: Downloading video info webpage
# [youtube] ZM-sV9zQPEs: Extracting video information
# [youtube] ZM-sV9zQPEs: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Tushar/Binary Tree Traversal.webm
# [download] 100% of 13.15MiB in 00:24.19KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Tushar/Binary Tree Traversal.wav
# Deleting original file ./data/wav_files/Tushar/Binary Tree Traversal.webm (pass -k to keep)
# 0
# [youtube:playlist] Downloading just video zm83jPHZ-jA because of --no-playlist
# [youtube] zm83jPHZ-jA: Downloading webpage
# [youtube] zm83jPHZ-jA: Downloading video info webpage
# [youtube] zm83jPHZ-jA: Extracting video information
# [youtube] zm83jPHZ-jA: Downloading MPD manifest
# [youtube] zm83jPHZ-jA: Downloading MPD manifest
# [dashsegments] Total fragments: 34
# [download] Destination: ./data/wav_files/Tushar/Binary Search Tree Search.m4a
# [download] 100% of 5.05MiB in 00:209.95KiB/s ETA 00:00:47
# [ffmpeg] Correcting container in "./data/wav_files/Tushar/Binary Search Tree Search.m4a"
# [ffmpeg] Destination: ./data/wav_files/Tushar/Binary Search Tree Search.wav
# Deleting original file ./data/wav_files/Tushar/Binary Search Tree Search.m4a (pass -k to keep)
# 0
# [youtube] LPFhl65R7ww: Downloading webpage
# [youtube] LPFhl65R7ww: Downloading video info webpage
# [youtube] LPFhl65R7ww: Extracting video information
# [youtube] LPFhl65R7ww: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Tushar/Binary Search  - Median of two sorted arrays of different sizes..webm
# [download] 100% of 20.33MiB in 00:52.28KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Tushar/Binary Search  - Median of two sorted arrays of different sizes..wav
# Deleting original file ./data/wav_files/Tushar/Binary Search  - Median of two sorted arrays of different sizes..webm (pass -k to keep)
# 0
# [youtube] BEweWXa5Twk: Downloading webpage
# [youtube] BEweWXa5Twk: Downloading video info webpage
# [youtube] BEweWXa5Twk: Extracting video information
# [youtube] BEweWXa5Twk: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Christen/FACE SURGERY WITH MAKEUP.webm
# [download] 100% of 12.23MiB in 00:29.31KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Christen/FACE SURGERY WITH MAKEUP.wav
# Deleting original file ./data/wav_files/Christen/FACE SURGERY WITH MAKEUP.webm (pass -k to keep)
# 0
# [youtube] s05QAgGSxgg: Downloading webpage
# [youtube] s05QAgGSxgg: Downloading video info webpage
# [youtube] s05QAgGSxgg: Extracting video information
# [youtube] s05QAgGSxgg: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Christen/Warm and Cozy Glam Makeup Tutorial.webm
# [download] 100% of 8.58MiB in 00:18.03KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Christen/Warm and Cozy Glam Makeup Tutorial.wav
# Deleting original file ./data/wav_files/Christen/Warm and Cozy Glam Makeup Tutorial.webm (pass -k to keep)
# 0
# [youtube] tQSoDmf5jLg: Downloading webpage
# [youtube] tQSoDmf5jLg: Downloading video info webpage
# [youtube] tQSoDmf5jLg: Extracting video information
# [youtube] tQSoDmf5jLg: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Christen/5 Minute Drugstore Makeup Tutorial.webm
# [download] 100% of 8.96MiB in 00:24.90KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Christen/5 Minute Drugstore Makeup Tutorial.wav
# Deleting original file ./data/wav_files/Christen/5 Minute Drugstore Makeup Tutorial.webm (pass -k to keep)
# 0
# [youtube] CB8qXiuG2L0: Downloading webpage
# [youtube] CB8qXiuG2L0: Downloading video info webpage
# [youtube] CB8qXiuG2L0: Extracting video information
# [youtube] CB8qXiuG2L0: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Christen/American VS Arab Makeup Tutorial.webm
# [download] 100% of 15.36MiB in 00:43.47KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Christen/American VS Arab Makeup Tutorial.wav
# Deleting original file ./data/wav_files/Christen/American VS Arab Makeup Tutorial.webm (pass -k to keep)
# 0
# [youtube] FHkbbIW8lsI: Downloading webpage
# [youtube] FHkbbIW8lsI: Downloading video info webpage
# [youtube] FHkbbIW8lsI: Extracting video information
# [youtube] FHkbbIW8lsI: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Christen/Fall First Impressions Makeup _ Huda Beauty, Kylie Jenner, Too Faced & More.webm
# [download] 100% of 14.88MiB in 01:05.34KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Christen/Fall First Impressions Makeup _ Huda Beauty, Kylie Jenner, Too Faced & More.wav
# Deleting original file ./data/wav_files/Christen/Fall First Impressions Makeup _ Huda Beauty, Kylie Jenner, Too Faced & More.webm (pass -k to keep)
# 0
# [youtube] 1Cjij7Yja_s: Downloading webpage
# [youtube] 1Cjij7Yja_s: Downloading video info webpage
# [youtube] 1Cjij7Yja_s: Extracting video information
# [youtube] 1Cjij7Yja_s: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Christen/Best Full Coverage Drugstore & Highend Foundations.m4a
# [download] 100% of 14.52MiB in 00:47.34KiB/s ETA 00:00
# [ffmpeg] Correcting container in "./data/wav_files/Christen/Best Full Coverage Drugstore & Highend Foundations.m4a"
# [ffmpeg] Destination: ./data/wav_files/Christen/Best Full Coverage Drugstore & Highend Foundations.wav
# Deleting original file ./data/wav_files/Christen/Best Full Coverage Drugstore & Highend Foundations.m4a (pass -k to keep)
# 0
# [youtube] Z9svINZiBdU: Downloading webpage
# [youtube] Z9svINZiBdU: Downloading video info webpage
# [youtube] Z9svINZiBdU: Extracting video information
# [youtube] Z9svINZiBdU: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Christen/American VS French Makeup Tutorial.webm
# [download] 100% of 15.19MiB in 00:59.50KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Christen/American VS French Makeup Tutorial.wav
# Deleting original file ./data/wav_files/Christen/American VS French Makeup Tutorial.webm (pass -k to keep)
# 0
# [youtube] 7H1siejx-9s: Downloading webpage
# [youtube] 7H1siejx-9s: Downloading video info webpage
# [youtube] 7H1siejx-9s: Extracting video information
# [youtube] 7H1siejx-9s: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Christen/Sweatproof Makeup and Styling My Lob Tutorial.webm
# [download] 100% of 13.12MiB in 00:37.37KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Christen/Sweatproof Makeup and Styling My Lob Tutorial.wav
# Deleting original file ./data/wav_files/Christen/Sweatproof Makeup and Styling My Lob Tutorial.webm (pass -k to keep)
# 0
# [youtube] PmBfZ6KjkAg: Downloading webpage
# [youtube] PmBfZ6KjkAg: Downloading video info webpage
# [youtube] PmBfZ6KjkAg: Extracting video information
# [youtube] PmBfZ6KjkAg: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Christen/Full Face First Impressions _ Trying New Makeup.webm
# [download] 100% of 12.40MiB in 00:48.31KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Christen/Full Face First Impressions _ Trying New Makeup.wav
# Deleting original file ./data/wav_files/Christen/Full Face First Impressions _ Trying New Makeup.webm (pass -k to keep)
# 0
# [youtube] YTVDwWtSjbc: Downloading webpage
# [youtube] YTVDwWtSjbc: Downloading video info webpage
# [youtube] YTVDwWtSjbc: Extracting video information
# [youtube] YTVDwWtSjbc: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Christen/My Everyday Makeup Routine.webm
# [download] 100% of 11.96MiB in 00:38.27KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Christen/My Everyday Makeup Routine.wav
# Deleting original file ./data/wav_files/Christen/My Everyday Makeup Routine.webm (pass -k to keep)
# 0
# [youtube] ofVkh8_K6T8: Downloading webpage
# [youtube] ofVkh8_K6T8: Downloading video info webpage
# [youtube] ofVkh8_K6T8: Extracting video information
# [youtube] ofVkh8_K6T8: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Blaha/Dallas McCarver Autopsy Released With Surprising Findings.m4a
# [download] 100% of 13.34MiB in 00:45.36KiB/s ETA 00:00
# [ffmpeg] Correcting container in "./data/wav_files/Blaha/Dallas McCarver Autopsy Released With Surprising Findings.m4a"
# [ffmpeg] Destination: ./data/wav_files/Blaha/Dallas McCarver Autopsy Released With Surprising Findings.wav
# Deleting original file ./data/wav_files/Blaha/Dallas McCarver Autopsy Released With Surprising Findings.m4a (pass -k to keep)
# 0
# [youtube] _iIi6BiT9Co: Downloading webpage
# [youtube] _iIi6BiT9Co: Downloading video info webpage
# [youtube] _iIi6BiT9Co: Extracting video information
# [youtube] _iIi6BiT9Co: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Blaha/Improving Our Weak Links - Learning To Love Our Most Challenging Lifts.m4a
# [download] 100% of 9.89MiB in 00:36.72KiB/s ETA 00:00
# [ffmpeg] Correcting container in "./data/wav_files/Blaha/Improving Our Weak Links - Learning To Love Our Most Challenging Lifts.m4a"
# [ffmpeg] Destination: ./data/wav_files/Blaha/Improving Our Weak Links - Learning To Love Our Most Challenging Lifts.wav
# Deleting original file ./data/wav_files/Blaha/Improving Our Weak Links - Learning To Love Our Most Challenging Lifts.m4a (pass -k to keep)
# 0
# [youtube] eG5wt9dKn7U: Downloading webpage
# [youtube] eG5wt9dKn7U: Downloading video info webpage
# [youtube] eG5wt9dKn7U: Extracting video information
# [youtube] eG5wt9dKn7U: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Blaha/Maintaining Size When The Enhanced Lifter Decides To Go Clean.m4a
# [download] 100% of 10.74MiB in 00:22.66KiB/s ETA 00:00
# [ffmpeg] Correcting container in "./data/wav_files/Blaha/Maintaining Size When The Enhanced Lifter Decides To Go Clean.m4a"
# [ffmpeg] Destination: ./data/wav_files/Blaha/Maintaining Size When The Enhanced Lifter Decides To Go Clean.wav
# Deleting original file ./data/wav_files/Blaha/Maintaining Size When The Enhanced Lifter Decides To Go Clean.m4a (pass -k to keep)
# 0
# [youtube] ClVmiorv_Rg: Downloading webpage
# [youtube] ClVmiorv_Rg: Downloading video info webpage
# [youtube] ClVmiorv_Rg: Extracting video information
# [youtube] ClVmiorv_Rg: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Blaha/Marc Lobliner Now Smaller Than Chris Jones Things That Make You Go Hmmmm....m4a
# [download] 100% of 9.59MiB in 00:28.53KiB/s ETA 00:00
# [ffmpeg] Correcting container in "./data/wav_files/Blaha/Marc Lobliner Now Smaller Than Chris Jones Things That Make You Go Hmmmm....m4a"
# [ffmpeg] Destination: ./data/wav_files/Blaha/Marc Lobliner Now Smaller Than Chris Jones Things That Make You Go Hmmmm....wav
# Deleting original file ./data/wav_files/Blaha/Marc Lobliner Now Smaller Than Chris Jones Things That Make You Go Hmmmm....m4a (pass -k to keep)
# 0
# [youtube] K1h5ZNE9OcE: Downloading webpage
# [youtube] K1h5ZNE9OcE: Downloading video info webpage
# [youtube] K1h5ZNE9OcE: Extracting video information
# [youtube] K1h5ZNE9OcE: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Blaha/Jason Blaha Kicked from TV Show and Ruins Girlfriend's Career _ Stolen Valor _ Tommy's Garage.webm
# [download] 100% of 15.83MiB in 00:52.86KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/Blaha/Jason Blaha Kicked from TV Show and Ruins Girlfriend's Career _ Stolen Valor _ Tommy's Garage.wav
# Deleting original file ./data/wav_files/Blaha/Jason Blaha Kicked from TV Show and Ruins Girlfriend's Career _ Stolen Valor _ Tommy's Garage.webm (pass -k to keep)
# 0
# [youtube] gklcO6MNZ04: Downloading webpage
# [youtube] gklcO6MNZ04: Downloading video info webpage
# [youtube] gklcO6MNZ04: Extracting video information
# [youtube] gklcO6MNZ04: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Blaha/Jason Blaha's Current Training Program & Philosophy - 220 Lbs Recomp.m4a
# [download] 100% of 9.99MiB in 00:24.50KiB/s ETA 00:00
# [ffmpeg] Correcting container in "./data/wav_files/Blaha/Jason Blaha's Current Training Program & Philosophy - 220 Lbs Recomp.m4a"
# [ffmpeg] Destination: ./data/wav_files/Blaha/Jason Blaha's Current Training Program & Philosophy - 220 Lbs Recomp.wav
# Deleting original file ./data/wav_files/Blaha/Jason Blaha's Current Training Program & Philosophy - 220 Lbs Recomp.m4a (pass -k to keep)
# 0
# [youtube] FWLj1jYJ1xc: Downloading webpage
# [youtube] FWLj1jYJ1xc: Downloading video info webpage
# [youtube] FWLj1jYJ1xc: Extracting video information
# [youtube] FWLj1jYJ1xc: Downloading MPD manifest
# [download] Destination: ./data/wav_files/Blaha/Jason Blaha Workout 11-27-2017 - Deadlift Day Grip It & Rip It!.m4a
# [download] 100% of 9.45MiB in 00:29.45KiB/s ETA 00:00
# [ffmpeg] Correcting container in "./data/wav_files/Blaha/Jason Blaha Workout 11-27-2017 - Deadlift Day Grip It & Rip It!.m4a"
# [ffmpeg] Destination: ./data/wav_files/Blaha/Jason Blaha Workout 11-27-2017 - Deadlift Day Grip It & Rip It!.wav
# Deleting original file ./data/wav_files/Blaha/Jason Blaha Workout 11-27-2017 - Deadlift Day Grip It & Rip It!.m4a (pass -k to keep)
# 0
# [youtube] TMubSggUOVE: Downloading webpage
# [youtube] TMubSggUOVE: Downloading video info webpage
# [youtube] TMubSggUOVE: Extracting video information
# [youtube] TMubSggUOVE: Downloading MPD manifest
# [download] Destination: ./data/wav_files/OChem/Math Videos -  How To Learn Basic Arithmetic Fast - Online Tutorial Lessons.webm
# [download] 100% of 58.59MiB in 02:31.66KiB/s ETA 00:00
# [ffmpeg] Destination: ./data/wav_files/OChem/Math Videos -  How To Learn Basic Arithmetic Fast - Online Tutorial Lessons.wav
# Deleting original file ./data/wav_files/OChem/Math Videos -  How To Learn Basic Arithmetic Fast - Online Tutorial Lessons.webm (pass -k to keep)
# 0

# %%
start = time.time()
with youtube_dl.YoutubeDL(ydl_opts) as ydl:
    ydl.download(['https://www.youtube.com/watch?v=Sagg08DrO5U'])
elapsed = (time.time() - start)
print(elapsed)
# Out:
# [youtube] Sagg08DrO5U: Downloading webpage
# [youtube] Sagg08DrO5U: Downloading video info webpage
# [youtube] Sagg08DrO5U: Extracting video information
# [youtube] Sagg08DrO5U: Downloading MPD manifest
# [download] Destination: Gandalf Sax guy 10 Hours-Sagg08DrO5U.webm
# [download] 100% of 625.82MiB in 00:3559MiB/s ETA 00:006
# [ffmpeg] Destination: Gandalf Sax guy 10 Hours-Sagg08DrO5U.wav
# Deleting original file Gandalf Sax guy 10 Hours-Sagg08DrO5U.webm (pass -k to keep)
# 0
# 224.6203258037567

# %% [markdown]
# ## Break Up Audio Files and Label into Map

# %% [markdown]
# ## Converting MP3s in a Directory to WAVs

# %% [markdown]
# Final product should iterate through folders in a directory such that each folder contains audio from a unique speaker. It will convert all MP3 files to uniform-length WAV audio segments and convert each of those audio segments to spectrograms.

# %%
import subprocess

subprocess.call(['./test/mp3_to_wav.sh'])
# Out:
# 255

# %%
import subprocess

in_path = '../Audio/audio1.wav'
out_path = '../Audio/out%03d.wav'

subprocess.call(['ffmpeg', '-i', in_path, '-f', 'segment', 
               '-segment_time', '10', '-c', 'copy', out_path])
# Out:
# 0

# %%
from IPython.display import Audio
Audio(X, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
X, sr = librosa.load('../Audio/out1004.wav')

# %% [markdown]
# test to see if faster to convert to spectrogram in bash or python

# %%
import glob
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
# %matplotlib inline

plt.plot(5,1);
specgram(X, Fs=sr);
plt.title("yuh");
plt.show();
